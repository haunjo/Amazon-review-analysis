# %%
import pandas as pd

# %%
df = pd.read_csv("amazon_reviews_us_Shoes_v1_00.tsv", sep='\t', error_bad_lines=False, warn_bad_lines = False)
# Out:
# /var/folders/9l/s6jwj9657tvf1kcmvh4dnkpw0000gn/T/ipykernel_86428/1275447602.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("amazon_reviews_us_Shoes_v1_00.tsv", sep='\t', error_bad_lines=False, warn_bad_lines = False)
# /var/folders/9l/s6jwj9657tvf1kcmvh4dnkpw0000gn/T/ipykernel_86428/1275447602.py:1: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("amazon_reviews_us_Shoes_v1_00.tsv", sep='\t', error_bad_lines=False, warn_bad_lines = False)

# %%
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     18069663  R3P2HIOQCIN5ZU  B000XB31C0       265024781
# 1          US     16251825  R12VVR0WH5Q24V  B00CFYZH5W       259035853
# 2          US     20381037   RNCCKB6TV5EEF  B00S8JNN3Q       666066660
# 3          US       108364  R2NZXYIVCGB13W  B00XFBPOQG       448483263
# 4          US     45449350  R2EQ1TG9IT3OEQ  B00SW64Y9W         7853171
#
#                                        product_title product_category  \
# 0  Minnetonka Men's Double Deerskin Softsole Mocc...            Shoes
# 1                        Teva Men's Pajaro Flip-Flop            Shoes
# 2                   Anne Klein Perfect Pair Wristlet            Shoes
# 3          adidas Men's 10K Lifestyle Runner Sneaker            Shoes
# 4  OverBling Sneakers for Men Casual Men Shoes Ge...            Shoes
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
df.shape
# Out:
# (4358820, 15)

# %%
df.columns
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date'],
#       dtype='object')

# %%
df = df.loc[:999999]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.dropna(axis=0)
# Out:
#        marketplace  customer_id       review_id  product_id  product_parent  \
# 0               US     18069663  R3P2HIOQCIN5ZU  B000XB31C0       265024781
# 1               US     16251825  R12VVR0WH5Q24V  B00CFYZH5W       259035853
# 2               US     20381037   RNCCKB6TV5EEF  B00S8JNN3Q       666066660
# 3               US       108364  R2NZXYIVCGB13W  B00XFBPOQG       448483263
# 4               US     45449350  R2EQ1TG9IT3OEQ  B00SW64Y9W         7853171
# ...            ...          ...             ...         ...             ...
# 999995          US     24538908  R2JXFR6AZ6IY2P  B0093DJ0RO       794738828
# 999996          US     11358775  R2BDAQRVRTZ1C9  B00HAUO7DO       314258855
# 999997          US     48274345  R2SPSQNZ9XKBOG  B00C3JX2T2       810915251
# 999998          US     32240682  R3TXQSFDHZRQ84  B00F0R7S26       480660821
# 999999          US     19191015  R3B3Y7EDHKCR54  B004EHKFKU       204607102
#
# ...

# %%
df.to_csv("amazon_shoes_100kreviews.tsv", sep='\t', encoding = "utf-8", index = False)
